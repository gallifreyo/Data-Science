# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("IMDB-Movie-Data.csv")

# %%
data = pd.read_csv("IMDB-Movie-Data.csv")

# %%
data = pd.read_csv("IMDB-Movie-Data.csv",encoding = "UTF-8", header=0)

# %%
data.head(50)
# Out:
#     Rank                                        Title  \
# 0      1                      Guardians of the Galaxy
# 1      2                                   Prometheus
# 2      3                                        Split
# 3      4                                         Sing
# 4      5                                Suicide Squad
# 5      6                               The Great Wall
# 6      7                                   La La Land
# 7      8                                     Mindhorn
# 8      9                           The Lost City of Z
# 9     10                                   Passengers
# 10    11      Fantastic Beasts and Where to Find Them
# 11    12                               Hidden Figures
# 12    13                                    Rogue One
# 13    14                                        Moana
# 14    15                                     Colossal
# 15    16                      The Secret Life of Pets
# ...

# %%
# os filmes mais bem Avaliados
sorted_df = data.sort_values(by=['Rating'], axis=0, ascending=False)
#mostra as posicoes da tabela
sorted_df[['Title','Director','Rating']].head(10) #5 primeiras posicoes
# Out:
#                 Title           Director  Rating
# 54    The Dark Knight  Christopher Nolan     9.0
# 80          Inception  Christopher Nolan     8.8
# 117            Dangal      Nitesh Tiwari     8.8
# 36       Interstellar  Christopher Nolan     8.6
# 96      Kimi no na wa     Makoto Shinkai     8.6
# 249  The Intouchables    Olivier Nakache     8.6
# 133          Whiplash    Damien Chazelle     8.5
# 64       The Prestige  Christopher Nolan     8.5
# 99       The Departed    Martin Scorsese     8.5
# 991  Taare Zameen Par         Aamir Khan     8.5

# %%
# edgecolor ='black'
#data.hist(column="Year",bins = 30,edgecolor ='black')
# Number of Movies
# Revenue (Millions)

data.Year.plot(kind = 'hist', bins = 40 ,edgecolor ='black', figsize = (9,6))
plt.xlabel("Years")
plt.ylabel("Number of Movies")
plt.show()

# %%
# scatter plot - grafico de dispersao

plt.scatter(data.Year, data.Rating, alpha = 0.28, label = "Movie", color = "red")
plt.xlabel("Years")
plt.ylabel("Ratings")
plt.legend(loc = "lower right")
plt.show()

# %%
# quero ver os filmes que mais faturaram

# ordena DataFrame por Operador de dificuldade convertidos em ordem decrescente
sorted_df = data.sort_values(by=['Revenue (Millions)'], axis=0, ascending=False)
#mostra as posicoes da tabela
sorted_df[['Title','Director','Revenue (Millions)']].head(10) #5 primeiras posicoes
# Out:
#                                           Title           Director  \
# 50   Star Wars: Episode VII - The Force Awakens        J.J. Abrams
# 87                                       Avatar      James Cameron
# 85                               Jurassic World    Colin Trevorrow
# 76                                 The Avengers        Joss Whedon
# 54                              The Dark Knight  Christopher Nolan
# 12                                    Rogue One     Gareth Edwards
# 119                                Finding Dory     Andrew Stanton
# 94                      Avengers: Age of Ultron        Joss Whedon
# 124                       The Dark Knight Rises  Christopher Nolan
# 578             The Hunger Games: Catching Fire   Francis Lawrence
#
#      Revenue (Millions)
# 50               936.63
# 87               760.51
# 85               652.18
# 76               623.28
# 54               533.32
# 12               532.17
# 119              486.29
# 94               458.99
# ...

# %%
# os piores filmes Avaliados

sorted_df = data.sort_values(by=['Rating'], axis=0, ascending=True)
#mostra as posicoes da tabela
sorted_df[['Title','Director','Year','Rating']].head(10) #5 primeiras posicoes
# Out:
#                        Title           Director  Year  Rating
# 829           Disaster Movie    Jason Friedberg  2008     1.9
# 42   Don't Fuck in the Woods      Shawn Burkett  2016     2.7
# 871     Dragonball Evolution         James Wong  2009     2.7
# 647                 Tall Men  Jonathan Holbrook  2016     3.2
# 968                  Wrecker     Micheal Bafaro  2015     3.5
# 890               The Intent      Femi Oyeniran  2016     3.5
# 49             The Last Face          Sean Penn  2016     3.7
# 269                  Satanic    Jeffrey G. Hunt  2016     3.7
# 525      Birth of the Dragon       George Nolfi  2016     3.9
# 401           The Black Room     Rolfe Kanefsky  2016     3.9

# %%
# fazer a soma dos faturamentos da industria de Filmes a cada ano

# fazer a media de faturamento

sorted_df = data.sort_values(by=['Year'], axis=0, ascending=False)

sorted_df[['Year','Revenue (Millions)']].head(10) #5 primeiras posicoes
# Out:
#      Year  Revenue (Millions)
# 999  2016               19.64
# 161  2016                1.80
# 647  2016                 NaN
# 234  2016               47.95
# 653  2016                9.39
# 231  2016                0.00
# 654  2016                 NaN
# 229  2016                 NaN
# 664  2016                0.28
# 225  2016                0.66

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
movies_time = data["Runtime (Minutes)"]
f,ax = plt.subplots(figsize=(14, 8))
sns.distplot(movies_time, bins=20, kde=False,rug=True, ax=ax);
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
data["Year"].value_counts()
# Out:
# 2016    297
# 2015    127
# 2014     98
# 2013     91
# 2012     64
# 2011     63
# 2010     60
# 2007     53
# 2008     52
# 2009     51
# 2006     44
# Name: Year, dtype: int64

# %%
sns.jointplot(x="Rating", y="Year", data=data)
